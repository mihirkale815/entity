# %%
import torch
import torch.autograd as autograd
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
torch.manual_seed(1)

# %%
def to_scalar(var):
    # returns a python float
    return var.view(-1).data.tolist()[0]


def argmax(vec):
    # return the argmax as a python int
    _, idx = torch.max(vec, 1)
    return to_scalar(idx)


def prepare_sequence(seq, to_ix):
    idxs = [to_ix[w] if w in to_ix else 29 for w in seq ]
    tensor = torch.LongTensor(idxs)
    return autograd.Variable(tensor)


# Compute log sum exp in a numerically stable way for the forward algorithm
def log_sum_exp(vec):
    max_score = vec[0, argmax(vec)]
    max_score_broadcast = max_score.view(1, -1).expand(1, vec.size()[1])
    return max_score + \
        torch.log(torch.sum(torch.exp(vec - max_score_broadcast)))

# %%
class BiLSTM_CRF(nn.Module):

    def __init__(self, vocab_size, tag_to_ix, embedding_dim, hidden_dim):
        super(BiLSTM_CRF, self).__init__()
        self.embedding_dim = embedding_dim
        self.hidden_dim = hidden_dim
        self.vocab_size = vocab_size
        self.tag_to_ix = tag_to_ix
        self.tagset_size = len(tag_to_ix)
        self.ix_to_tag = {v:k for k,v in self.tag_to_ix.items()}

        self.word_embeds = nn.Embedding(vocab_size, embedding_dim)
        self.lstm = nn.LSTM(embedding_dim, hidden_dim // 2,
                            num_layers=1, bidirectional=True)

        # Maps the output of the LSTM into tag space.
        self.hidden2tag = nn.Linear(hidden_dim, self.tagset_size)

        # Matrix of transition parameters.  Entry i,j is the score of
        # transitioning *to* i *from* j.
        self.transitions = nn.Parameter(
            torch.randn(self.tagset_size, self.tagset_size))

        # These two statements enforce the constraint that we never transfer
        # to the start tag and we never transfer from the stop tag
        self.transitions.data[tag_to_ix[START_TAG], :] = -10000
        self.transitions.data[:, tag_to_ix[STOP_TAG]] = -10000

        self.hidden = self.init_hidden()

    def init_hidden(self):
        return (autograd.Variable(torch.randn(2, 1, self.hidden_dim // 2)),
                autograd.Variable(torch.randn(2, 1, self.hidden_dim // 2)))

    def _forward_alg(self, feats):
        # Do the forward algorithm to compute the partition function
        init_alphas = torch.Tensor(1, self.tagset_size).fill_(-10000.)
        # START_TAG has all of the score.
        init_alphas[0][self.tag_to_ix[START_TAG]] = 0.

        # Wrap in a variable so that we will get automatic backprop
        forward_var = autograd.Variable(init_alphas)

        # Iterate through the sentence
        for feat in feats:
            alphas_t = []  # The forward variables at this timestep
            for next_tag in range(self.tagset_size):
                # broadcast the emission score: it is the same regardless of
                # the previous tag
                emit_score = feat[next_tag].view(
                    1, -1).expand(1, self.tagset_size)
                # the ith entry of trans_score is the score of transitioning to
                # next_tag from i
                trans_score = self.transitions[next_tag].view(1, -1)
                # The ith entry of next_tag_var is the value for the
                # edge (i -> next_tag) before we do log-sum-exp
                next_tag_var = forward_var + trans_score + emit_score
                # The forward variable for this tag is log-sum-exp of all the
                # scores.
                alphas_t.append(log_sum_exp(next_tag_var))
            forward_var = torch.cat(alphas_t).view(1, -1)
        terminal_var = forward_var + self.transitions[self.tag_to_ix[STOP_TAG]]
        alpha = log_sum_exp(terminal_var)
        return alpha

    def _get_lstm_features(self, sentence):
        self.hidden = self.init_hidden()
        embeds = self.word_embeds(sentence).view(len(sentence), 1, -1)
        lstm_out, self.hidden = self.lstm(embeds, self.hidden)
        lstm_out = lstm_out.view(len(sentence), self.hidden_dim)
        lstm_feats = self.hidden2tag(lstm_out)
        return lstm_feats

    def _score_sentence(self, feats, tags):
        # Gives the score of a provided tag sequence
        score = autograd.Variable(torch.Tensor([0]))
        tags = torch.cat([torch.LongTensor([self.tag_to_ix[START_TAG]]), tags])
        for i, feat in enumerate(feats):
            score = score + \
                self.transitions[tags[i + 1], tags[i]] + feat[tags[i + 1]]
        score = score + self.transitions[self.tag_to_ix[STOP_TAG], tags[-1]]
        return score

    def _viterbi_decode(self, feats):
        backpointers = []

        # Initialize the viterbi variables in log space
        init_vvars = torch.Tensor(1, self.tagset_size).fill_(-10000.)
        init_vvars[0][self.tag_to_ix[START_TAG]] = 0

        # forward_var at step i holds the viterbi variables for step i-1
        forward_var = autograd.Variable(init_vvars)
        for feat in feats:
            bptrs_t = []  # holds the backpointers for this step
            viterbivars_t = []  # holds the viterbi variables for this step

            for next_tag in range(self.tagset_size):
                # next_tag_var[i] holds the viterbi variable for tag i at the
                # previous step, plus the score of transitioning
                # from tag i to next_tag.
                # We don't include the emission scores here because the max
                # does not depend on them (we add them in below)
                next_tag_var = forward_var + self.transitions[next_tag]
                best_tag_id = argmax(next_tag_var)
                bptrs_t.append(best_tag_id)
                viterbivars_t.append(next_tag_var[0][best_tag_id])
            # Now add in the emission scores, and assign forward_var to the set
            # of viterbi variables we just computed
            forward_var = (torch.cat(viterbivars_t) + feat).view(1, -1)
            backpointers.append(bptrs_t)

        # Transition to STOP_TAG
        terminal_var = forward_var + self.transitions[self.tag_to_ix[STOP_TAG]]
        best_tag_id = argmax(terminal_var)
        path_score = terminal_var[0][best_tag_id]

        # Follow the back pointers to decode the best path.
        best_path = [best_tag_id]
        for bptrs_t in reversed(backpointers):
            best_tag_id = bptrs_t[best_tag_id]
            best_path.append(best_tag_id)
        # Pop off the start tag (we dont want to return that to the caller)
        start = best_path.pop()
        assert start == self.tag_to_ix[START_TAG]  # Sanity check
        best_path.reverse()
        return path_score, best_path

    def neg_log_likelihood(self, sentence, tags):
        feats = self._get_lstm_features(sentence)
        forward_score = self._forward_alg(feats)
        gold_score = self._score_sentence(feats, tags)
        return forward_score - gold_score

    def forward(self, sentence):  # dont confuse this with _forward_alg above.
        # Get the emission scores from the BiLSTM
        lstm_feats = self._get_lstm_features(sentence)

        # Find the best path, given the features.
        score, tag_seq = self._viterbi_decode(lstm_feats)
        return score, tag_seq

# %%
def load_data(path):
    f = open(path)
    data = [line.split("\t") for line in f]
    data = [ (tokens.split()[1:-1],tags.split()[1:-1]) for (tokens,tags) in data]
    f.close()
    return data

def create_word_to_ix(training_data):
    word_to_ix = {}
    for (sentence, tags) in training_data:
        for word in sentence:
            if word not in word_to_ix:
                word_to_ix[word] = len(word_to_ix)
    return word_to_ix

def create_tag_to_ix(training_data,START_TAG=None,STOP_TAG=None):
    if START_TAG and STOP_TAG : tag_to_ix = {START_TAG: 0, STOP_TAG: 1}
    else : tag_to_ix = {}
    for (sentence, tags) in training_data:
        for tag in tags:
            if tag not in tag_to_ix:
                tag_to_ix[tag] = len(tag_to_ix)
    return tag_to_ix

# %%
training_data = load_data("../data/mit-movie-1/processed/train.bio")
testing_data = load_data("../data/mit-movie-1/processed/test.bio")

# %%
START_TAG = "BOS"
STOP_TAG = "EOS"
EMBEDDING_DIM = 5
HIDDEN_DIM = 4

tag_to_ix = create_tag_to_ix(training_data,START_TAG,STOP_TAG)
word_to_ix = create_word_to_ix(training_data)

# %%
len(word_to_ix),len(tag_to_ix)
# Out:
# (6710, 27)

# %%
for tag in tag_to_ix : print(tag)
# Out:
# BOS
# EOS
# O
# B-ACTOR
# I-ACTOR
# B-YEAR
# B-TITLE
# B-GENRE
# I-GENRE
# B-DIRECTOR
# I-DIRECTOR
# B-SONG
# I-SONG
# B-PLOT
# I-PLOT
# B-REVIEW
# B-CHARACTER
# I-CHARACTER
# B-RATING
# B-RATINGS_AVERAGE
# I-RATINGS_AVERAGE
# I-TITLE
# I-RATING
# B-TRAILER
# I-TRAILER
# I-REVIEW
# I-YEAR

# %%
model = BiLSTM_CRF(len(word_to_ix), tag_to_ix, EMBEDDING_DIM, HIDDEN_DIM)
optimizer = optim.SGD(model.parameters(), lr=0.01, weight_decay=1e-4)

# %%
# Check predictions before training
precheck_sent = prepare_sequence(training_data[0][0], word_to_ix)
precheck_tags = torch.LongTensor([tag_to_ix[t] for t in training_data[0][1]])
print(model(precheck_sent))
# Out:
# (Variable containing:
#  12.0993
# [torch.FloatTensor of size 1]
# , [3, 21, 24, 3, 21])

# %%
sentences_in = [prepare_sequence(sentence, word_to_ix) for (sentence,tags) in training_data]


# Make sure prepare_sequence from earlier in the LSTM section is loaded
for epoch in range(
        10):  # again, normally you would NOT do 300 epochs, it is toy data
    print("epoch = ",epoch)
    for idx ,(sentence, tags) in enumerate(training_data[:-1]):
        if idx%1000 == 0 : print(idx)
        # Step 1. Remember that Pytorch accumulates gradients.
        # We need to clear them out before each instance
        model.zero_grad()

        # Step 2. Get our inputs ready for the network, that is,
        # turn them into Variables of word indices.
        sentence_in = sentences_in[idx]
        targets = torch.LongTensor([tag_to_ix[t] for t in tags])

        # Step 3. Run our forward pass.
        neg_log_likelihood = model.neg_log_likelihood(sentence_in, targets)

        # Step 4. Compute the loss, gradients, and update the parameters by
        # calling optimizer.step()
        neg_log_likelihood.backward()
        optimizer.step()

# Check predictions after training
precheck_sent = prepare_sequence(training_data[0][0], word_to_ix)
print(model(precheck_sent))
# We got it!
# Out:
# epoch =  0
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# epoch =  1
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# epoch =  2
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# epoch =  3
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000

# %%
ix_to_tag = {v:k for k,v in tag_to_ix.items()}

# %%
def persist_output(path,preds,data):
    fout = open(path,"w")
    for row in range(0,len(preds)):
        predicted = preds[row][1]
        actual = data[row][1]
        sentence = data[row][0]
        predicted = [ix_to_tag[ix] for ix in predicted]
        print(predicted,actual,sentence)
        for idx in range(len(predicted)):
            fout.write(" ".join([sentence[idx],'UNK','UNK',actual[idx],predicted[idx]]) + "\n")
    fout.close()

# %%
path = "train.res"
precheck_sents = [prepare_sequence(training_data[i][0], word_to_ix) for i in range(len(training_data))]
preds = [model(precheck_sent) for precheck_sent in precheck_sents[:-1]]
persist_output(path,preds,training_data)
# Out:
# ['i',
#  'want',
#  'to',
#  'find',
#  'the',
#  'movie',
#  'with',
#  'scarlett',
#  'o',
#  'hara',
#  'in',
#  'it']

# %%
path = "test.res"
precheck_sents = [prepare_sequence(testing_data[i][0], word_to_ix) for i in range(len(testing_data))]
preds = [model(precheck_sent) for precheck_sent in precheck_sents[:-1]]

# %%
persist_output(path,preds,testing_data)
# Out:
# ['O', 'O', 'O', 'B-ACTOR', 'I-ACTOR', 'B-GENRE', 'O', 'B-TITLE', 'I-TITLE'] ['O', 'O', 'O', 'O', 'B-GENRE', 'I-GENRE', 'O', 'B-YEAR', 'I-YEAR'] ['are', 'there', 'any', 'good', 'romantic', 'comedies', 'out', 'right', 'now']
# ['O', 'O', 'O', 'O', 'O', 'B-GENRE', 'O', 'O'] ['O', 'O', 'O', 'O', 'O', 'B-PLOT', 'I-PLOT', 'I-PLOT'] ['show', 'me', 'a', 'movie', 'about', 'cars', 'that', 'talk']
# ['O', 'O', 'B-RATINGS_AVERAGE', 'I-RATINGS_AVERAGE', 'O', 'O', 'O', 'B-ACTOR', 'I-ACTOR'] ['O', 'O', 'B-RATINGS_AVERAGE', 'I-RATINGS_AVERAGE', 'O', 'O', 'O', 'B-ACTOR', 'I-ACTOR'] ['list', 'the', 'five', 'star', 'rated', 'movies', 'starring', 'mel', 'gibson']
# ['O', 'B-GENRE', 'I-GENRE', 'O', 'O', 'B-TITLE', 'I-TITLE', 'I-TITLE'] ['O', 'B-GENRE', 'I-GENRE', 'O', 'O', 'O', 'O', 'B-YEAR'] ['what', 'science', 'fiction', 'films', 'have', 'come', 'out', 'recently']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-RATINGS_AVERAGE', 'I-RATINGS_AVERAGE', 'O'] ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-TITLE', 'I-TITLE', 'O'] ['did', 'the', 'same', 'director', 'make', 'all', 'of', 'the', 'harry', 'potter', 'movies']
# ['O', 'O', 'B-YEAR', 'B-GENRE', 'O'] ['O', 'O', 'B-YEAR', 'B-GENRE', 'O'] ['show', 'me', '1980s', 'action', 'movies']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE'] ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-TITLE', 'I-TITLE', 'I-TITLE'] ['what', 'is', 'the', 'name', 'of', 'the', 'third', 'movie', 'in', 'the', 'star', 'trek', 'series']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-RATINGS_AVERAGE', 'I-RATINGS_AVERAGE', 'O'] ['O', 'O', 'O', 'O', 'B-SONG', 'O', 'O', 'B-TITLE', 'I-TITLE', 'I-TITLE'] ['can', 'you', 'get', 'a', 'soundtrac', 'for', 'the', 'harry', 'potter', 'films']
# ['O', 'O', 'B-GENRE', 'I-GENRE', 'O', 'B-TITLE', 'I-TITLE'] ['O', 'O', 'B-GENRE', 'I-GENRE', 'O', 'B-YEAR', 'I-YEAR'] ['find', 'me', 'science', 'fiction', 'movies', 'since', '2005']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PLOT'] ['O', 'O', 'O', 'O', 'B-YEAR', 'O', 'O', 'B-ACTOR', 'I-ACTOR'] ['what', 'is', 'the', 'most', 'current', 'movie', 'featuring', 'mat', 'damon']
# ['O', 'O', 'O', 'O', 'B-ACTOR', 'I-ACTOR', 'O', 'O', 'B-TITLE'] ['O', 'O', 'O', 'O', 'B-ACTOR', 'I-ACTOR', 'O', 'O', 'B-CHARACTER'] ['show', 'me', 'films', 'where', 'jim', 'carrey', 'is', 'a', 'detective']
# ['O', 'B-DIRECTOR', 'I-DIRECTOR', 'O', 'O', 'B-GENRE', 'O', 'O', 'B-YEAR'] ['O', 'B-ACTOR', 'I-ACTOR', 'O', 'O', 'B-GENRE', 'O', 'O', 'B-YEAR'] ['did', 'george', 'clooney', 'make', 'a', 'musical', 'in', 'the', '1980s']
# ['O', 'O', 'O', 'O', 'B-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE'] ['O', 'O', 'O', 'O', 'O', 'B-ACTOR', 'I-ACTOR', 'O', 'B-ACTOR', 'I-ACTOR'] ['show', 'me', 'films', 'with', 'both', 'matt', 'damon', 'ad', 'ben', 'affleck']
# ['O', 'O', 'O', 'O', 'O'] ['O', 'O', 'O', 'B-TITLE', 'O'] ['what', 'is', 'the', 'borrowers', 'movie']
# ['O', 'O', 'O', 'O', 'O', 'O', 'B-RATING', 'I-RATING'] ['O', 'O', 'O', 'O', 'O', 'O', 'B-RATING', 'I-RATING'] ['have', 'u', 'movie', 'hm', 'about', 'to', 'pg', '18']
# ['O', 'O', 'B-RATING', 'O', 'O', 'B-TITLE', 'I-TITLE'] ['O', 'O', 'B-RATING', 'O', 'O', 'B-PLOT', 'I-PLOT'] ['find', 'rated', 'g', 'films', 'with', 'flying', 'cars']
# ['O', 'O', 'O', 'O', 'O', 'B-DIRECTOR', 'I-DIRECTOR', 'O'] ['O', 'O', 'O', 'B-REVIEW', 'O', 'B-DIRECTOR', 'I-DIRECTOR', 'O'] ['what', 'was', 'the', 'best', 'rated', 'stanley', 'kubrick', 'film']
# ['O', 'O', 'O', 'O', 'O', 'O', 'B-DIRECTOR', 'I-DIRECTOR', 'O', 'O', 'O'] ['O', 'O', 'O', 'O', 'O', 'O', 'B-DIRECTOR', 'I-DIRECTOR', 'O', 'B-PLOT', 'I-PLOT'] ['are', 'there', 'any', 'films', 'directed', 'by', 'shawn', 'levy', 'about', 'large', 'families']
# ['O', 'B-RATING', 'O', 'O', 'O', 'B-GENRE', 'O', 'O', 'O', 'B-YEAR'] ['O', 'B-RATING', 'O', 'O', 'O', 'B-PLOT', 'O', 'O', 'O', 'B-YEAR'] ['list', 'pg', 'rated', 'movies', 'about', 'cars', 'released', 'in', 'the', '1990s']
# ['O', 'O', 'B-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE'] ['O', 'O', 'O', 'B-RATINGS_AVERAGE', 'I-RATINGS_AVERAGE', 'O', 'O', 

# ['O', 'O', 'O', 'O', 'O', 'O', 'B-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE'] ['O', 'O', 'O', 'B-PLOT', 'I-PLOT', 'I-PLOT', 'I-PLOT', 'I-PLOT', 'O', 'B-TITLE', 'I-TITLE'] ['which', 'movies', 'were', 'based', 'off', 'of', 'video', 'games', 'besides', 'resident', 'evil']
# ['O', 'B-ACTOR', 'I-ACTOR', 'I-ACTOR', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ACTOR', 'I-ACTOR'] ['O', 'B-ACTOR', 'I-ACTOR', 'I-ACTOR', 'O', 'O', 'O', 'B-PLOT', 'O', 'O', 'B-CHARACTER', 'I-CHARACTER'] ['did', 'dame', 'judy', 'dench', 'star', 'in', 'a', 'british', 'film', 'about', 'queen', 'elizabeth']
# ['O', 'O', 'O', 'B-GENRE', 'O', 'O', 'O', 'O', 'O'] ['O', 'O', 'O', 'B-GENRE', 'I-GENRE', 'O', 'B-DIRECTOR', 'I-DIRECTOR', 'O'] ['present', 'list', 'of', 'family', 'movies', 'that', 'chris', 'columbus', 'directed']
# ['O', 'O', 'O', 'O', 'B-PLOT', 'O', 'O', 'O', 'O'] ['O', 'O', 'O', 'O', 'B-PLOT', 'O', 'O', 'O', 'O'] ['find', 'a', 'movie', 'with', 'dogs', 'as', 'the', 'main', 'character']
# ['O', 'O', 'O', 'O', 'B-TITLE', 'I-TITLE'] ['O', 'O', 'O', 'O', 'B-PLOT', 'I-PLOT'] ['show', 'me', 'movies', 'about', 'horse', 'racing']
# ['O', 'O', 'B-ACTOR', 'I-ACTOR', 'O', 'O', 'B-TITLE', 'I-TITLE'] ['O', 'O', 'B-ACTOR', 'I-ACTOR', 'O', 'O', 'O', 'B-YEAR'] ['show', 'me', 'morgan', 'freeman', 'movies', 'from', 'the', '90s']
# ['O', 'O', 'O', 'O', 'O', 'B-ACTOR', 'I-ACTOR', 'O', 'O', 'B-ACTOR', 'I-ACTOR'] ['O', 'O', 'O', 'O', 'O', 'O', 'B-ACTOR', 'I-ACTOR', 'O', 'B-ACTOR', 'I-ACTOR'] ['find', 'me', 'the', 'movies', 'that', 'starred', 'anne', 'hathaway', 'and', 'julie', 'andrews']
# ['O', 'B-ACTOR', 'I-ACTOR', 'O', 'O', 'B-RATING', 'O', 'O'] ['O', 'B-ACTOR', 'I-ACTOR', 'O', 'O', 'B-RATING', 'I-RATING', 'O'] ['has', 'sandra', 'bullock', 'made', 'any', 'g', 'rated', 'movies']
# ['B-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'O', 'O', 'O', 'B-YEAR'] ['O', 'O', 'B-TITLE', 'I-TITLE', 'O', 'O', 'O', 'B-YEAR'] ['list', 'the', 'dirty', 'harry', 'films', 'from', 'the', '1980s']
# ['O', 'O', 'O', 'O', 'O'] ['O', 'O', 'O', 'O', 'B-PLOT'] ['show', 'me', 'movies', 'about', 'strippers']
# ['O', 'O', 'O', 'B-ACTOR', 'I-ACTOR', 'B-GENRE', 'I-GENRE', 'O', 'O', 'O', 'O', 'B-RATINGS_AVERAGE', 'I-RATINGS_AVERAGE'] ['O', 'O', 'O', 'B-ACTOR', 'I-ACTOR', 'B-GENRE', 'I-GENRE', 'O', 'O', 'O', 'O', 'B-REVIEW', 'I-REVIEW'] ['are', 'there', 'any', 'meg', 'ryan', 'romantic', 'comedy', 'movies', 'that', 'are', 'considered', 'must', 'see']
# ['O', 'O', 'B-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE'] ['O', 'O', 'B-DIRECTOR', 'I-DIRECTOR', 'O', 'O'] ['what', 'was', 'james', 'camerons', 'directorial', 'debut']
# ['O', 'O', 'O', 'O', 'O', 'O', 'B-RATINGS_AVERAGE', 'I-RATINGS_AVERAGE'] ['O', 'O', 'B-RATINGS_AVERAGE', 'I-RATINGS_AVERAGE', 'O', 'O', 'B-RATINGS_AVERAGE', 'I-RATINGS_AVERAGE'] ['what', 'are', 'top', '50', 'movies', 'of', 'all', 'time']
# ['O', 'O', 'B-GENRE', 'O', 'O', 'B-GENRE', 'O'] ['O', 'O', 'B-GENRE', 'O', 'O', 'B-ACTOR', 'I-ACTOR'] ['find', 'me', 'comedy', 'movies', 'with', 'liam', 'hemsworth']
# ['O', 'O', 'O', 'O', 'O', 'B-TITLE', 'I-TITLE', 'I-TITLE'] ['O', 'O', 'O', 'O', 'B-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE'] ['i', 'want', 'to', 'see', 'cradle', '2', 'the', 'grave']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-TITLE'] ['O', 'O', 'O', 'B-REVIEW', 'I-REVIEW', 'I-REVIEW', 'O', 'B-YEAR'] ['what', 'was', 'the', 'most', 'popular', 'movie', 'from', '2004']
# ['O', 'O', 'O', 'B-RATING', 'O', 'O', 'O', 'B-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE'] ['O', 'O', 'O', 'B-RATING', 'I-RATING', 'O', 'O', 'B-PLOT', 'I-PLOT', 'I-PLOT', 'I-PLOT', 'I-PLOT', 'I-PLOT'] ['what', 'is', 'the', 'g', 'rated', 'movie', 'about', 'rabbits', 'looking', 'for', 'a', 'new', 'home']
# ['O', 'B-DIRECTOR', 'I-DIRECTOR', 'O', 'O', 'O', 'O', 'O', 'O'] ['O', 'O', 'B-PLOT', 'O', 'O', 'O', 'O', 'O', 'B-RATINGS_AVERAGE'] ['what', 'latest', '3d', 'movie', 'of', 'any', 'genre', 'is', 'reccommend']
# ['O', 'O', 'O', 'O', 'B-DIRECTOR', 'I-DIRECTOR', 'O', 'B-ACTOR', 'I-ACTOR', 'O', 'O'] ['O', 'O', 'O', 'O', 'B-ACTOR', 'I-ACTOR', 'O', 'B-ACTOR', 'I-ACTOR', 'O', 'O'] ['how', 'many', 'movies', 'have', 'tim', 'burton', 'and', 'johnny', 'depp', 'done', 'together']
# ['B-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE'] ['O', 'O', 'O', 'O', 'B-ACTOR', 'I-ACTOR', 'O', 'B-CHARACTER', 'I-CHARACTER'] ['how', 'many', 'times', 'has', 'matt', 'damon', 'been', 'jason', 'bourne']
# ['O', 'O', 'O', 'B-ACTOR', 'I-ACTOR', 'O', 'O', 'B-GENRE', 'O', 'B-GENRE', 'O', 'O'] ['O', 'O', 'B-YEAR', 'B-GENRE', 'I-GENRE', 'O', 'O', 'O', 'O', 'B-PLOT', 'O', 'B-PLOT'] ['whats', 'the', 'latetest', 'foreign', 'romantic', 'movie', 'with', 'lots', 'of', 'sex', 'and', 'sadness']
# ['O', 'O', 'O', 'B-RATINGS_AVERAGE', 'I-RATINGS_AVERAGE', 'O', 'O', 'O', 'B-YEAR'] ['O', 'O', 'O', 'B-ACTOR', 'I-ACTOR', 'O', 'O', 'O', 'B-YEAR'] ['list', 'movies', 'with', 'jeremy', 'piven', 'released', 'in', 'the', '1990s']
# ['O', 'O', 'O', 'O', 'O', 'B-GENRE', 'O', 'O', 'O'] ['O', 'O', 'O', 'O', 'O', 'B-GENRE', 'I-GENRE', 'O', 'B-ACTOR'] ['show', 'me', 'the', 'collection', 'of', 'action', 'movies', 'of', 'arnold']
# ['O', 'O', 'B-DIRECTOR', 'I-DIRECTOR', 'O', 'O', 'O', 'O', 'B-RATING', 'I-RATING'] ['O', 'O', 'B-GENRE', 'I-GENRE', 'I-GENRE', 'O', 'O', 'O', 'B-RATING', 'I-RATING'] ['are', 'there', 'comic', 'book', 'movies', 'that', 'are', 'over', 'pg', '13']
# ['O', 'B-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE'] ['O', 'O', 'B-TITLE', 'O', 'O', 'O'] ['the', 'new', 'batman', 'movie', 'looks', 'epic']
# ['O', 'O', 'O', 'O', 'B-TITLE', 'I-TITLE'] ['O', 'O', 'O', 'O', 'O', 'B-RATINGS_AVERAGE'] ['show', 'me', 'movies', 'who', 'won', 'awards']
# ['O', 'O', 'O', 'O', 'O', 'B-TITLE', 'I-TITLE', 'O', 'O'] ['O', 
', 'O', 'O', 'O', 'B-DIRECTOR', 'I-DIRECTOR', 'O', 'O', 'O', 'B-YEAR'] ['O', 'O', 'O', 'O', 'O', 'B-DIRECTOR', 'I-DIRECTOR', 'O', 'O', 'B-YEAR'] ['show', 'me', 'movies', 'directed', 'by', 'alexander', 'payne', 'from', 'the', '2000s']
# ['O', 'O', 'O', 'O', 'B-GENRE', 'O', 'O', 'B-TITLE'] ['O', 'O', 'O', 'B-REVIEW', 'B-GENRE', 'O', 'O', 'B-YEAR'] ['what', 'are', 'some', 'good', 'horror', 'movies', 'from', '1974']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-TITLE', 'I-TITLE', 'I-TITLE', 'O', 'O'] ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-SONG', 'I-SONG', 'I-SONG', 'O', 'O'] ['find', 'me', 'a', 'movie', 'with', 'the', 'song', 'over', 'the', 'rainbow', 'in', 'it']
# ['O', 'O', 'O', 'B-DIRECTOR', 'I-DIRECTOR', 'O'] ['B-GENRE', 'I-GENRE', 'I-GENRE', 'I-GENRE', 'I-GENRE', 'I-GENRE'] ['i', 'want', 'a', '1960s', 'zombie', 'flick']
# ['B-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'O', 'O', 'O'] ['O', 'O', 'B-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'O', 'O', 'O'] ['how', 'many', 'lord', 'of', 'the', 'rings', 'films', 'are', 'there']
# ['O', 'O', 'O', 'B-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE'] ['O', 'O', 'O', 'O', 'B-TRAILER', 'O', 'B-TITLE', 'I-TITLE'] ['show', 'me', 'the', 'latest', 'trailer', 'for', 'the', 'avengers']
# ['O', 'O', 'O', 'O', 'B-TITLE', 'I-TITLE'] ['O', 'O', 'B-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE'] ['who', 'directed', 'beaty', 'and', 'the', 'beast']
# ['O', 'O', 'O', 'B-GENRE', 'O', 'B-TITLE', 'I-TITLE'] ['O', 'O', 'O', 'B-GENRE', 'O', 'B-ACTOR', 'I-ACTOR'] ['show', 'me', 'a', 'comedy', 'with', 'nick', 'swardson']
# ['B-TITLE', 'I-TITLE', 'O', 'O', 'O', 'O', 'B-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE'] ['O', 'O', 'O', 'O', 'O', 'O', 'B-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'O'] ['how', 'many', 'movies', 'are', 'in', 'the', 'sex', 'and', 'the', 'city', 'series']
# ['O', 'B-ACTOR', 'I-ACTOR', 'O', 'B-ACTOR', 'I-ACTOR', 'O', 'B-RATINGS_AVERAGE', 'I-RATINGS_AVERAGE'] ['O', 'B-DIRECTOR', 'I-DIRECTOR', 'O', 'B-ACTOR', 'I-ACTOR', 'O', 'O', 'O'] ['did', 'martin', 'scorsese', 'and', 'johnny', 'depp', 'ever', 'work', 'together']
# ['O', 'O', 'O', 'O', 'B-TITLE', 'I-TITLE'] ['O', 'O', 'O', 'O', 'B-TITLE', 'I-TITLE'] ['who', 'directed', 'the', 'film', 'the', 'lorax']
# ['O', 'B-ACTOR', 'I-ACTOR', 'O', 'O', 'O', 'B-GENRE', 'O'] ['O', 'B-ACTOR', 'I-ACTOR', 'O', 'O', 'O', 'B-GENRE', 'O'] ['has', 'samuel', 'jackson', 'been', 'in', 'any', 'thriller', 'flicks']
# ['B-TITLE'] ['B-CHARACTER'] ['todd']
# ['O', 'O', 'O', 'O', 'O', 'B-GENRE', 'O'] ['O', 'O', 'O', 'O', 'O', 'B-CHARACTER', 'I-CHARACTER'] ['what', 'was', 'the', 'film', 'about', 'brandon', 'teena']
# ['O', 'B-TITLE', 'I-TITLE', 'I-TITLE'] ['O', 'O', 'O', 'B-TITLE'] ['who', 'starred', 'in', 'drive']
# ['O', 'O', 'B-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE'] ['O', 'O', 'B-TITLE', 'I-TITLE', 'I-TITLE', 'O'] ['what', 'is', 'kingdom', 'of', 'heaven', 'rated']
# ['B-TITLE', 'I-TITLE'] ['B-CHARACTER', 'I-CHARACTER'] ['super', 'man']
# ['O', 'O', 'O', 'B-DIRECTOR', 'I-DIRECTOR', 'O', 'O', 'B-TITLE', 'I-TITLE'] ['O', 'O', 'O', 'B-PLOT', 'I-PLOT', 'O', 'O', 'B-PLOT', 'I-PLOT'] ['what', 'is', 'a', 'monty', 'python', 'film', 'about', 'king', 'arthur']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-TITLE', 'I-TITLE'] ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-TITLE', 'I-TITLE'] ['who', 'was', 'the', 'actor', 'in', 'the', 'movie', 'teen', 'wolf']
# ['O', 'O', 'O', 'B-GENRE', 'O', 'B-ACTOR', 'I-ACTOR'] ['O', 'O', 'B-GENRE', 'I-GENRE', 'O', 'B-ACTOR', 'I-ACTOR'] ['show', 'me', 'classic', 'comedies', 'starring', 'bill', 'murray']
# ['B-YEAR', 'O', 'B-ACTOR', 'I-ACTOR', 'O'] ['O', 'O', 'B-TITLE', 'O', 'O'] ['when', 'did', 'underworld', 'come', 'out']
# ['O', 'O', 'O', 'O', 'B-GENRE', 'O'] ['O', 'O', 'O', 'O', 'B-PLOT', 'I-PLOT'] ['find', 'a', 'film', 'with', 'animated', 'skeletons']
# ['O', 'B-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'O'] ['O', 'B-GENRE', 'O', 'O', 'B-ACTOR', 'I-ACTOR', 'O'] ['what', 'animated', 'voices', 'has', 'eddie', 'murphy', 'done']
# ['O', 'O', 'O', 'B-RATING', 'I-RATING', 'O'] ['O', 'O', 'B-RATING', 'I-RATING', 'B-GENRE', 'O'] ['please', 'list', 'rated', 'r', 'noir', 'films']
# ['B-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE'] ['O', 'O', 'O', 'B-TRAILER', 'O', 'B-TITLE'] ['show', 'me', 'the', 'trailer', 'for', 'rage']
# ['O', 'O', 'O', 'O', 'O', 'O'] ['O', 'O', 'O', 'O', 'O', 'B-PLOT'] ['are', 'there', 'any', 'films', 'with', 'volcanos']
# ['O', 'O', 'O', 'O', 'B-RATINGS_AVERAGE', 'I-RATINGS_AVERAGE'] ['O', 'O', 'B-TITLE', 'I-TITLE', 'I-TITLE', 'B-RATING'] ['what', 'is', 'act', 'of', 'valor', 'rated']
# ['O', 'O', 'B-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE'] ['O', 'O', 'B-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE'] ['who', 'directed', 'terminator', '2', 'judgement', 'day']
# ['O', 'B-GENRE', 'O', 'O', 'B-RATING'] ['O', 'B-GENRE', 'O', 'O', 'B-PLOT'] ['what', 'horror', 'movies', 'have', 'snakes']
# ['O', 'O', 'O', 'O', 'O', 'B-GENRE', 'O', 'O', 'O', 'B-TITLE', 'I-TITLE'] ['O', 'O', 'O', 'O', 'O', 'B-ACTOR', 'I-ACTOR', 'O', 'O', 'B-TITLE', 'I-TITLE'] ['what', 'was', 'the', 'name', 'of', 'clive', 'owens', 'character', 'in', 'sin', 'city']
# ['B-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'O', 'O', 'O'] ['O', 'O', 'B-TITLE', 'I-TITLE', 'O', 'O', 'O'] ['how', 'many', 'charlies', 'angels', 'movies', 'are', 'there']
# ['O', 'O', 'O', 'O', 'O', 'B-RATING', 'O', 'B-GENRE', 'O'] ['O', 'O', 'O', 'O', 'O', 'B-RATING', 'O', 'B-GENRE', 'O'] ['i', 'am', 'looking', 'for', 'a', 'pg', 'rated', 'disney', 'movie']
# ['O', 'B-TITLE', 'I-TITLE', 'I-TITLE', 'O', 'O', 'O'] ['O', 'O', 'B-TITLE', 'I-TITLE', 'O', 'O', 'O'] ['how', 'many', 'star', 'wars', 'films', 'are', 'there']
# ['O', 'O', 'O', 'O', 'O'] ['O', 'O', 'O', 'B-TITLE', 'I-TITLE'] ['who', 'is', 'directing', 'the', 'hobbit']
# ['O', 'O', 'O', 'B-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE'] ['O', 'O', 'O', 'O', 'O', 'B-TITLE', 'I-TITLE'] ['what', 'did', 'critics', 'think', 'of', 'j', 'edgar']
# ['O', 'O', 'O', 'O', 'O', 'B-TITLE', 'I-TITLE'] ['O', 'O', 'O', 'O', 'O', 'B-TITLE', 'I-TITLE'] ['who', 'starred', 'in', 'the', 'movie', 'jurassic', 'park']
# ['O', 'O', 'O', 'O', 'B-DIRECTOR', 'I-DIRECTOR', 'O', 'B-DIRECTOR', 'I-DIRECTOR'] ['O', 'O', 'O', 'O', 'B-DIRECTOR', 'I-DIRECTOR', 'O', 'B-YEAR', 'I-YEAR'] ['how', 'many', 'movies', 'has', 'clint', 'eastwood', 'directed', 'since', '1995']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'] ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-YEAR'] ['what', 'is', 'the', 'name', 'of', 'the', 'highest', 'grossing', 'movie', 'of', '2011']
# ['O', 'O', 'O', 'O', 'B-GENRE', 'O'] ['O', 'O', 'B-TITLE', 'I-TITLE', 'O', 'O'] ['when', 'did', 'the', 'game', 'come', 'out']
# ['O', 'B-ACTOR', 'I-ACTOR', 'O', 'O', 'B-RATINGS_AVERAGE', 'I-RATINGS_AVERAGE', 'O'] ['O', 'B-ACTOR', 'I-ACTOR', 'O', 'O', 'B-REVIEW', 'I-REVIEW', 'O'] ['has', 'john', 'candy', 'made', 'any', 'must', 'see', 'movies']
# ['O', 'O', 'O', 'B-GENRE', 'O', 'O', 'B-TITLE', 'I-TITLE'] ['O', 'O', 'O', 'B-GENRE', 'O', 'O', 'B-ACTOR', 'I-ACTOR'] ['are', 'there', 'any', 'horror', 'films', 'with', 'don', 'rickles']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-TITLE', 'I-TITLE'] ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-SONG', 'I-SONG'] ['find', 'me', 'the', 'movie', 'with', 'the', 'song', 'married', 'life']
# ['O', 'O', 'O', 'B-RATINGS_AVERAGE', 'I-RATINGS_AVERAGE', 'B-GENRE', 'I-GENRE', 'O'] ['O', 'O', 'O', 'B-RATINGS_AVERAGE', 'I-RATINGS_AVERAGE', 'B-GENRE', 'I-GENRE', 'O'] ['show', 'me', 'an', 'oscar', 'winning', 'science', 'fiction', 'movie']
# ['O', 'O', 'O', 'O', 'O', 'B-ACTOR', 'I-ACTOR', 'O', 'B-TITLE', 'I-TITLE'] ['O', 'O', 'O', 'O', 'O', 'B-PLOT', 'B-GENRE', 'O', 'O', 'B-YEAR'] ['give', 'me', 'a', 'list', 'of', 'legal', 'dramas', 'from', 'the', '70s']
# ['O', 'O'] ['B-TITLE', 'I-TITLE'] ['rainbow', '6']
# ['O', 'O', 'O', 'B-DIRECTOR', 'I-DIRECTOR', 'O'] ['O', 'O', 'O', 'B-ACTOR', 'I-ACTOR', 'O'] ['show', 'me', 'a', 'wes', 'craven', 'movie']
# ...
# ['O', 'B-GENRE', 'B-RATING', 'I-RATING', 'O', 'O', 'O', 'B-ACTOR', 'I-ACTOR'] ['O', 'B-GENRE', 'B-RATING', 'I-RATING', 'O', 'O', 'O', 'B-ACTOR', 'I-ACTOR'] ['list', 'animated', 'pg', '13', 'rated', 'movie', 'starring', 'sean', 'connery']
# ['O', 'O', 'B-GENRE', 'O', 'O', 'O', 'B-RATINGS_AVERAGE', 'I-RATINGS_AVERAGE', 'O', 'O', 'B-DIRECTOR', 'I-DIRECTOR', 'O', 'O', 'O', 'B-YEAR', 'I-YEAR'] ['O', 'B-PLOT', 'B-GENRE', 'O', 'O', 'O', 'B-RATINGS_AVERAGE', 'I-RATINGS_AVERAGE', 'O', 'O', 'O', 'B-DIRECTOR', 'I-DIRECTOR', 'O', 'O', 'B-YEAR', 'I-YEAR'] ['list', 'isolation', 'adventure', 'movies', 'that', 'are', 'critically', 'acclaimed', 'and', 'directed', 'by', 'jack', 'sholder', 'in', 'the', 'past', 'decade']
# ['O', 'O', 'B-TITLE', 'I-TITLE', 'I-TITLE'] ['O', 'O', 'O', 'B-TITLE', 'I-TITLE'] ['list', 'movies', 'named', 'grave', 'encounters']
# ['O', 'O', 'O', 'O', 'B-TITLE', 'I-TITLE'] ['O', 'O', 'O', 'O', 'B-ACTOR', 'I-ACTOR'] ['list', 'some', 'films', 'starring', 'hugh', 'jackman']
# ['O', 'O', 'B-GENRE', 'O'] ['O', 'O', 'B-GENRE', 'O'] ['list', 'some', 'mockumentary', 'movies']
# ['O', 'O', 'B-GENRE', 'O', 'O', 'O'] ['O', 'O', 'B-GENRE', 'O', 'O', 'B-PLOT'] ['list', 'some', 'war', 'movies', 'with', 'nazi']
# ['O', 'O', 'O', 'B-GENRE', 'O', 'O', 'O', 'O', 'B-YEAR'] ['O', 'B-RATINGS_AVERAGE', 'I-RATINGS_AVERAGE', 'B-GENRE', 'O', 'O', 'O', 'O', 'B-YEAR'] ['list', 'well', 'rated', 'mystery', 'movies', 'from', 'the', 'year', '2000']
# ['O', 'O', 'B-GENRE', 'O', 'O', 'O', 'B-RATINGS_AVERAGE', 'I-RATINGS_AVERAGE', 'B-RATING'] ['O', 'O', 'B-GENRE', 'O', 'O', 'O', 'B-PLOT', 'O', 'B-RATING'] ['name', 'a', 'action', 'movie', 'with', 'a', 'shootout', 'rated', 'pg']
# ['O', 'O', 'B-GENRE', 'O', 'B-TITLE', 'I-TITLE'] ['O', 'O', 'B-GENRE', 'O', 'B-DIRECTOR', 'I-DIRECTOR'] ['name', 'a', 'comedy', 'from', 'francois', 'truffaut']
# ['O', 'O', 'B-GENRE', 'O', 'O', 'B-ACTOR', 'I-ACTOR'] ['O', 'O', 'B-GENRE', 'O', 'O', 'B-ACTOR', 'I-ACTOR'] ['name', 'a', 'fantasy', 'film', 'with', 'sandra', 'bullock']
# ['O', 'O', 'B-GENRE', 'O', 'B-DIRECTOR', 'I-DIRECTOR'] ['O', 'O', 'B-GENRE', 'O', 'B-DIRECTOR', 'I-DIRECTOR'] ['name', 'a', 'mystery', 'by', 'orson', 'welles']
# ['O', 'O', 'B-GENRE', 'O', 'B-TITLE', 'I-TITLE'] ['O', 'O', 'B-GENRE', 'O', 'B-ACTOR', 'I-ACTOR'] ['name', 'a', 'mystery', 'starring', 'kevin', 'spacey']
# ['O', 'O', 'B-GENRE', 'I-GENRE', 'O', 'O', 'B-PLOT'] ['O', 'O', 'B-GENRE', 'I-GENRE', 'O', 'O', 'B-PLOT'] ['name', 'a', 'sci', 'fi', 'about', 'a', 'human']
# ['O', 'O', 'B-GENRE', 'I-GENRE', 'O', 'B-ACTOR', 'I-ACTOR', 'O', 'O', 'B-YEAR', 'I-YEAR'] ['O', 'O', 'B-GENRE', 'I-GENRE', 'O', 'B-PLOT', 'I-PLOT', 'O', 'O', 'B-YEAR', 'I-YEAR'] ['name', 'a', 'science', 'fiction', 'with', 'artificial', 'intelligence', 'from', 'the', '2010', 's']
# ['O', 'O', 'B-GENRE', 'O', 'O', 'B-ACTOR', 'I-ACTOR', 'O', 'O', 'B-RATINGS_AVERAGE', 'I-RATINGS_AVERAGE'] ['O', 'O', 'B-GENRE', 'O', 'O', 'B-ACTOR', 'I-ACTOR', 'O', 'O', 'B-RATINGS_AVERAGE', 'I-RATINGS_AVERAGE'] ['name', 'a', 'teen', 'movie', 'with', 'steve', 'mcqueen', 'that', 'was', 'received', 'well']
# ['O', 'O', 'B-GENRE', 'O', 'O', 'O', 'B-DIRECTOR', 'I-DIRECTOR', 'I-DIRECTOR'] ['O', 'O', 'B-GENRE', 'O', 'O', 'O', 'B-DIRECTOR', 'I-DIRECTOR', 'I-DIRECTOR'] ['name', 'an', 'adventure', 'movie', 'directed', 'by', 'francis', 'ford', 'coppola']
# ['O', 'O', 'B-ACTOR', 'I-ACTOR', 'B-YEAR', 'B-GENRE', 'O'] ['O', 'O', 'B-DIRECTOR', 'I-DIRECTOR', 'I-DIRECTOR', 'B-GENRE', 'O'] ['name', 'some', 'guillermo', 'del', 'toro', 'action', 'movies']
# ['O', 'O', 'B-DIRECTOR', 'I-DIRECTOR', 'O', 'O', 'B-GENRE'] ['O', 'O', 'B-DIRECTOR', 'I-DIRECTOR', 'O', 'O', 'B-GENRE'] ['name', 'some', 'john', 'huston', 'films', 'about', 'children']
# ['O', 'O', 'O', 'O', 'B-ACTOR', 'I-ACTOR'] ['O', 'O', 'O', 'O', 'B-ACTOR', 'I-ACTOR'] ['name', 'some', 'movies', 'starring', 'robert', 'redford']
# ['O', 'B-ACTOR', 'I-ACTOR', 'O', 'B-TITLE'] ['O', 'B-ACTOR', 'I-ACTOR', 'O', 'B-TITLE'] ['was', 'mel', 'gibson', 'in', 'inception']
# ['O', 'B-RATING', 'O', 'O', 'O', 'B-GENRE', 'I-GENRE', 'O', 'B-RATINGS_AVERAGE', 'I-RATINGS_AVERAGE', 'I-RATINGS_AVERAGE'] ['O', 'B-RATING', 'O', 'O', 'O', 'B-ACTOR', 'I-ACTOR', 'O', 'B-RATINGS_AVERAGE', 'I-RATINGS_AVERAGE', 'O'] ['what', 'r', 'rated', 'movies', 'with', 'john', 'cusak', 'got', 'all', 'right', 'ratings']
# ['O', 'O', 'O', 'B-GENRE', 'O', 'B-RATING', 'O', 'B-ACTOR', 'I-ACTOR'] ['O', 'O', 'O', 'B-GENRE', 'O', 'B-RATING', 'O', 'B-ACTOR', 'I-ACTOR'] ['what', 'is', 'a', 'fantasy', 'rated', 'pg', 'starring', 'christian', 'bale']
# ['O', 'O', 'O', 'O', 'B-RATING', 'I-RATING', 'B-GENRE', 'O', 'B-DIRECTOR', 'I-DIRECTOR', 'O', 'O', 'B-YEAR', 'I-YEAR'] ['O', 'O', 'O', 'B-RATINGS_AVERAGE', 'B-RATING', 'I-RATING', 'B-GENRE', 'O', 'B-ACTOR', 'I-ACTOR', 'O', 'O', 'B-YEAR', 'I-YEAR'] ['what', 'is', 'a', 'good', 'pg', '13', 'drama', 'with', 'andrew', 'keegan', 'in', 'the', '2010', 's']
# ['O', 'O', 'B-ACTOR', 'I-ACTOR', 'O', 'O', 'B-GENRE'] ['O', 'O', 'O', 'O', 'O', 'O', 'B-GENRE'] ['what', 'movie', 'can', 'be', 'called', 'a', 'thriller']
# ['O', 'B-GENRE', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PLOT'] ['O', 'B-GENRE', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PLOT'] ['what', 'police', 'movie', 'is', 'there', 'that', 'you', 'would', 'recommend', 'where', 'somebody', 'is', 'kidnapped']
# ['O', 'O', 'B-RATING', 'I-RATING', 'B-GENRE', 'O', 'O', 'B-DIRECTOR', 'I-DIRECTOR'] ['O', 'O', 'B-RATING', 'I-RATING', 'B-GENRE', 'O', 'O', 'B-DIRECTOR', 'I-DIRECTOR'] ['whats', 'a', 'pg', '13', 'crime', 'movie', 'by', 'orson', 'welles']
# ['O', 'O', 'B-GENRE', 'O', 'O', 'B-DIRECTOR', 'I-DIRECTOR', 'O', 'O', 'B-ACTOR', 'I-ACTOR'] ['O', 'O', 'B-GENRE', 'O', 'O', 'B-DIRECTOR', 'I-DIRECTOR', 'O', 'O', 'B-RATINGS_AVERAGE', 'I-RATINGS_AVERAGE'] ['whats', 'a', 'comedy', 'directed', 'by', 'david', 'fincher', 'that', 'was', 'highly', 'liked']
# ['O', 'O', 'B-GENRE', 'O', 'B-ACTOR', 'I-ACTOR'] ['O', 'O', 'B-GENRE', 'O', 'B-PLOT', 'I-PLOT'] ['whats', 'a', 'documentary', 'about', 'youth', 'identity']
# ['O', 'O', 'O', 'B-GENRE', 'O', 'O', 'O', 'B-TITLE', 'I-TITLE'] ['O', 'O', 'O', 'B-GENRE', 'O', 'O', 'B-PLOT', 'I-PLOT', 'I-PLOT'] ['whats', 'a', 'good', 'action', 'film', 'about', 'on', 'the', 'run']
# ['O', 'O', 'O', 'B-RATING', 'O', 'O', 'O', 'O', 'O', 'O', 'B-YEAR', 'O', 'B-ACTOR', 'I-ACTOR', 'I-ACTOR'] ['O', 'O', 'O', 'B-RATING', 'O', 'O', 'O', 'O', 'O', 'O', 'B-YEAR', 'O', 'O', 'B-ACTOR', 'I-ACTOR'] ['who', 'directed', 'the', 'r', 'rated', 'film', 'made', 'in', 'the', 'year', '2000', 'that', 'starred', 'helen', 'barkin']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-YEAR', 'I-YEAR', 'O', 'O', 'O'] ['O', 'O', 'O', 'O', 'O', 'O', 'B-REVIEW', 'O', 'O', 'O', 'B-TITLE', 'I-TITLE', 'O', 'O', 'O'] ['i', 'would', 'like', 'to', 'get', 'the', 'details', 'of', 'the', 'movie', 'purple', 'rain', 'on', 'imdb', 'com']
# ['B-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE'] ['O', 'B-REVIEW', 'O', 'B-TITLE'] ['show', 'blogs', 'regarding', 'evita']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE'] ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-REVIEW', 'O', 'B-CHARACTER', 'I-CHARACTER'] ['could', 'you', 'please', 'show', 'me', 'a', 'website', 'with', 'reviews', 'of', 'indiana', 'jones']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE'] ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-REVIEW', 'O', 'B-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE'] ['could', 'you', 'send', 'me', 'to', 'a', 'website', 'with', 'user', 'reviews', 'of', 'willy', 'wonka', 'the', 'chocolate', 'factory']
# ['O', 'B-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE'] ['O', 'O', 'O', 'B-REVIEW', 'O', 'O', 'O', 'O', 'B-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'O'] ['what', 'do', 'you', 'think', 'the', 'best', 'part', 'of', 'a', 'hard', 'day', 's', 'night', 'was']
# ['B-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE'] ['O', 'O', 'O', 'O', 'O', 'O', 'B-TRAILER', 'O', 'B-TITLE', 'I-TITLE', 'I-TITLE'] ['can', 'u', 'please', 'show', 'me', 'the', 'trailer', 'of', 'kiss', 'me', 'kate']
# ['B-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE'] ['O', 'O', 'O', 'O', 'B-TRAILER', 'O', 'B-TITLE', 'I-TITLE', 'I-TITLE'] ['can', 'i', 'see', 'the', 'trailer', 'for', 'kiss', 'me', 'kate']
# ['O', 'O', 'O', 'O', 'O', 'B-YEAR', 'I-YEAR', 'I-YEAR', 'I-YEAR', 'O', 'O', 'O'] ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-TRAILER', 'O', 'O', 'O'] ['please', 'show', 'me', 'some', 'of', 'indiana', 's', 'major', 'scenes', 'in', 'the', 'movie']
# ['O', 'B-GENRE', 'O', 'O', 'O', 'B-ACTOR', 'I-ACTOR', 'O', 'O', 'B-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE'] ['O', 'O', 'O', 'O', 'O', 'O', 'B-TRAILER', 'O', 'B-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE'] ['where', 'can', 'i', 'see', 'some', 'short', 'clips', 'of', 'a', 'hard', 'day', 's', 'night']
# ['O', 'O', 'O', 'O', 'O', 'O', 'B-YEAR', 'O', 'O', 'O', 'O', 'O', 'B-TITLE', 'I-TITLE', 'I-TITLE', 'O', 'O'] ['O', 'O', 'O', 'O', 'O', 'O', 'B-YEAR', 'O', 'O', 'O', 'O', 'O', 'O', 'B-CHARACTER', 'I-CHARACTER', 'O', 'O'] ['what', 'was', 'the', 'name', 'of', 'that', '1997', 'movie', 'that', 'had', 'a', 'character', 'named', 'dr', 'evil', 'in', 'it']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-TITLE', 'I-TITLE', 'I-TITLE', 'O', 'O', 'B-YEAR'] ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-CHARACTER', 'I-CHARACTER', 'O', 'O', 'B-YEAR'] ['which', 'is', 'the', 'film', 'in', 'which', 'a', 'major', 'role', 'was', 'done', 'by', 'dr', 'evil', 'released', 'in', '1997']
# ['O', 'O', 'O', 'O', 'O', 'O', 'B-DIRECTOR', 'I-DIRECTOR', 'O', 'O', 'B-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'O', 'O'] ['O', 'O', 'O', 'O', 'O', 'O', 'B-DIRECTOR', 'I-DIRECTOR', 'O', 'O', 'B-CHARACTER', 'I-CHARACTER', 'O', 'B-CHARACTER', 'O', 'O'] ['what', 'is', 'the', 'movie', 'directed', 'by', 'george', 'lucas', 'which', 'casts', 'darth', 'vader', 'and', 'yoda', 'in', 'it']
# ['O', 'O', 'O', 'B-DIRECTOR', 'I-DIRECTOR', 'O', 'O', 'B-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE'] ['O', 'O', 'O', 'B-DIRECTOR', 'I-DIRECTOR', 'O', 'O', 'B-CHARACTER', 'O', 'B-CHARACTER', 'I-CHARACTER'] ['what', 'is', 'that', 'george', 'lucas', 'movie', 'with', 'yoda', 'and', 'darth', 'vader']
# ['O', 'O', 'O', 'B-YEAR', 'O', 'B-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'O', 'O'] ['O', 'O', 'O', 'B-YEAR', 'O', 'B-CHARACTER', 'I-CHARACTER', 'O', 'B-CHARACTER', 'I-CHARACTER', 'I-CHARACTER', 'O', 'O'] ['which', 'movie', 'of', '2010', 'had', 'buzz', 'lightyear', 'and', 'mr', 'potato', 'head', 'in', 'it']
# ['O', 'B-YEAR', 'I-YEAR', 'O', 'O', 'O', 'O', 'B-TITLE', 'I-TITLE', 'I-TITLE', 'O', 'O'] ['O', 'B-YEAR', 'I-YEAR', 'O', 'O', 'O', 'O', 'B-SONG', 'I-SONG', 'I-SONG', 'O', 'O'] ['what', '1960', 's', 'movie', 'had', 'that', 'song', 'my', 'favourite', 'things', 'in', 'it']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-TITLE', 'I-TITLE', 'I-TITLE', 'O', 'O'] ['O', 'O', 'O', 'O', 'O', 'O', 'B-YEAR', 'I-YEAR', 'O', 'O', 'O', 'O', 'B-SONG', 'I-SONG', 'I-SONG', 'O', 'O'] ['what', 'is', 'that', 'movie', 'from', 'the', '60', 's', 'that', 'had', 'the', 'song', 'my', 'favorite', 'things', 'in', 'it']
# ['O', 'O', 'O', 'B-YEAR', 'I-YEAR', 'O', 'O', 'O', 'O', 'B-TITLE', 'I-TITLE', 'I-TITLE', 'O', 'O'] ['O', 'O', 'O', 'B-YEAR', 'I-YEAR', 'O', 'O', 'O', 'O', 'B-SONG', 'I-SONG', 'I-SONG', 'O', 'O'] ['there', 'is', 'a', '1960', 's', 'movie', 'where', 'the', 'song', 'my', 'favorite', 'things', 'is', 'sung']
# ['O', 'O', 'O', 'O', 'O', 'B-TITLE', 'I-TITLE', 'I-TITLE', 'O', 'O'] ['O', 'O', 'O', 'O', 'O', 'B-SONG', 'I-SONG', 'I-SONG', 'O', 'O'] ['what', 'movie', 'did', 'the', 'song', 'come', 'what', 'may', 'play', 'in']
# ['B-TITLE', 'I-TITLE'] ['B-TITLE', 'I-TITLE'] ['american', 'beauty']
# ['O', 'B-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE'] ['B-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE'] ['crouching', 'tiger', ',', 'hidden', 'dragon']
# ['B-TITLE', 'I-TITLE', 'I-TITLE'] ['B-TITLE', 'I-TITLE', 'I-TITLE'] ['million', 'dollar', 'baby']
# ['O', 'O', 'O'] ['B-TITLE', 'I-TITLE', 'I-TITLE'] ['life', 'of', 'oharu']
# ['O', 'O'] ['B-TITLE', 'I-TITLE'] ['the', 'leopard']
# ['B-TITLE', 'I-TITLE', 'I-TITLE'] ['B-TITLE', 'I-TITLE', 'I-TITLE'] ['empire', 'strikes', 'back']
# ['O', 'O', 'O', 'O', 'B-RATINGS_AVERAGE', 'I-RATINGS_AVERAGE'] ['B-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE'] ['snow', 'white', 'and', 'the', 'seven', 'dwarfs']
# ['B-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE'] ['B-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE'] ['monty', 'python', 'and', 'the', 'holy', 'grail']
# ['O', 'B-TITLE'] ['B-TITLE', 'I-TITLE'] ['the', 'graduate']
# ['B-TITLE', 'I-TITLE'] ['B-TITLE', 'I-TITLE'] ['blow', 'up']
# ['B-TITLE', 'I-TITLE'] ['B-TITLE', 'I-TITLE'] ['american', 'graffiti']
# ['B-TITLE', 'I-TITLE'] ['B-TITLE', 'I-TITLE'] ['oliver', 'twist']
# ['B-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE'] ['B-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE'] ['lord', 'of', 'the', 'rings', 'the', 'fellowship', 'of', 'the', 'rings']
# ['B-TITLE', 'I-TITLE'] ['B-TITLE', 'I-TITLE'] ['sunset', 'boulevard']
# ['O', 'O', 'O'] ['B-TITLE', 'I-TITLE', 'I-TITLE'] ['sansho', 'the', 'bailiff']
# ['B-TITLE', 'I-TITLE'] ['B-TITLE', 'I-TITLE'] ['pulp', 'fiction']
# ['B-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE'] ['B-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE'] ['lord', 'of', 'the', 'rings', 'the', 'return', 'of', 'the', 'king']
# ['O', 'O'] ['B-TITLE', 'I-TITLE'] ['broken', 'blossoms']
# ['B-TITLE', 'I-TITLE', 'I-TITLE'] ['B-TITLE', 'I-TITLE', 'I-TITLE'] ['wizard', 'of', 'oz']
# ['O'] ['B-TITLE'] ['freaks']
# ['O', 'B-TITLE', 'I-TITLE', 'I-TITLE'] ['B-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE'] ['the', 'children', 'of', 'paradise']
# ['B-TITLE', 'I-TITLE', 'I-TITLE'] ['B-TITLE', 'I-TITLE', 'I-TITLE'] ['city', 'of', 'god']
# ['B-TITLE', 'I-TITLE'] ['B-TITLE', 'I-TITLE'] ['finding', 'nemo']
# ['B-YEAR', 'I-YEAR'] ['B-TITLE', 'I-TITLE'] ['duck', 'soup']
# ['O', 'B-TITLE', 'I-TITLE'] ['O', 'O', 'B-TRAILER'] ['play', 'the', 'trailer']
# ['O', 'B-TITLE', 'I-TITLE'] ['O', 'O', 'B-TRAILER'] ['play', 'the', 'trailer']
# ['O', 'O', 'O', 'O', 'B-DIRECTOR', 'I-DIRECTOR'] ['O', 'B-TRAILER', 'O', 'B-TITLE', 'I-TITLE', 'I-TITLE'] ['play', 'trailer', 'of', 'on', 'stranger', 'tides']
# ['O', 'B-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE'] ['O', 'O', 'B-TRAILER', 'O', 'B-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE'] ['play', 'the', 'trailer', 'of', 'dark', 'of', 'the', 'moon']
# ['O', 'B-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE'] ['O', 'B-TRAILER', 'B-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE'] ['play', 'trailer', 'dark', 'of', 'the', 'moon']
# ['O', 'B-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE'] ['O', 'O', 'B-TRAILER', 'B-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE'] ['play', 'the', 'trailer', 'dark', 'of', 'the', 'moon']
# ['O', 'O', 'B-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE'] ['O', 'O', 'B-TITLE', 'I-TITLE', 'I-TITLE', 'B-REVIEW'] ['show', 'me', 'the', 'good', 'thief', 'review']
# ['O', 'B-ACTOR', 'I-ACTOR', 'O'] ['O', 'B-CHARACTER', 'I-CHARACTER', 'O'] ['any', 'james', 'bond', 'movies']
# ['O', 'O', 'O', 'B-GENRE', 'O', 'O', 'B-TITLE', 'I-TITLE'] ['O', 'O', 'O', 'B-GENRE', 'O', 'O', 'B-CHARACTER', 'I-CHARACTER'] ['find', 'me', 'some', 'adventure', 'movies', 'with', 'indiana', 'jones']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ACTOR', 'I-ACTOR', 'I-ACTOR'] ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-CHARACTER', 'I-CHARACTER', 'I-CHARACTER'] ['what', 's', 'the', 'title', 'of', 'the', 'movie', 'about', 'captain', 'jack', 'sparrow']

# %%
word_to_ix['a']
# Out:
# 29

# %%
sent = precheck_sents[2:]
embeds = model.word_embeds(sent).view(len(sent), 1, -1)

# %%
precheck_sents = sorted(precheck_sents,key=lambda x : len(x),reverse=True)

# %%
nn.utils.rnn.pack_padded_sequence()

# %%
tensor = torch.LongTensor(idxs)
return autograd.Variable(tensor)
